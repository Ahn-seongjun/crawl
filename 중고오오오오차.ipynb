# %%
#동적 생성되는 data 크롤링
#Selenium 모듈 사용
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import selenium
from selenium import webdriver

# %% [markdown]
# ### 관련 메서드
# - get(url) : url에 접근하는 메서드
#
# #### 페이지 단일 element에 접근하는 메서드
# - find_element_by_name('html_name')
# - find_element_by_id('html_id')
# - find_element_by_xpath('패스경로') : 스크립트 실행 경로를 찾아 접근
#
#
# #### 페이지의 여러 element에 접근하는 메서드
# - find_element_by_class_selector('html slelctor')
# - find_element_by_class_name('html_class')
# - find_element_by_tag_name('htm tag')
#
# #### Webdriver 객체 생성
# - driver = webdriver.Chrome(드라이버경로)
#
# #### 접근한 페이지 source 추출
# - html=diver.page_source

# %%
# 크롬 드라이버를 통한 네이버 접속

driver = webdriver.Chrome("./driver/chromedriver")
driver.get("http://www.m-park.co.kr/buy/my_car_list.asp?gotopage=1&sListOrder=DemoDay_D&sPageSize=40&sSearch=1&sListType=list")

# %%
driver.page_source
# Out:
# '<html lang="ko"><head>\n\n\t<title>전체차량 : 내차구매</title>\n    <meta charset="utf-8">\n<meta name="viewport" content="width=1700">\n<meta name="format-detection" content="telephone=no">\n<meta name="theme-color" content="#0d643a">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="og:site_name" content="www.m-park.co.kr">\n<title>엠파크 공식 사이트</title>\n<link rel="shortcut icon" href="/2018_renew/images/layout/favicon.ico" type="image/x-icon">\n<link rel="apple-touch-icon" href="/2018_renew/images/layout/apple-touch-icon.png">\n<!-- // JG20200710_0001 ST -->\n<link rel="stylesheet" type="text/css" href="/src/comm/js/jquery-ui/themes/base/jquery-ui.min.css">\n<!-- JG20200710_0001 ED /// -->\n<link rel="stylesheet" type="text/css" href="/2018_renew/css/style.css">\n<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script src="/2018_renew/js/jquery-1.12.4.min.js"></script>\n<script src="/2018_renew/js/ui.js"></script><style type="text/css">.imgLiquid img {visibility:hidden}</style>\n<script src="/2018_renew/js/common.js"></script>\n<!-- // JG20200710_0002 ST -->\n<script type="text/javascript" src="/src/comm/js/jquery-ui/jquery-ui.min.js"></script>\n<script type="text/javascript" src="/src/comm/js/comm.js"></script>\n<!-- JG20200710_0002 ED /// -->\n<meta name="description" content="엠파크 중고차 매매단지 – 단지 내 실제로 있는 차량만 판매, 헛걸음 시 100만원 보상">\n<!--\n<script type="application/ld+json">\n{\n "@context": "http://schema.org",\n "@type": "Person",\n "name": "엠파크 공식사이트",\n "url": "http://www.m-park.co.kr",\n "sameAs": [\n   "https://www.facebook.com/mparkdrive",\n   "https://blog.naver.com/mparkdrive",\n   "https://post.naver.com/mparkdrive",\n   "https://www.youtube.com/channel/UC823YaEzv6t8OSLzLgQIqyw"\n ]\n}\n</script>\n-->\n\n<meta property="og:image" content="http://www.m-park.co.kr/2018_renew/images/contents/sns_share.jpg">\n<meta property="og:title" content="전체차량 : 내차구매">\n<meta property="og:url" content="http://www.m-park.co.kr/buy/my_car_list.asp?gotopage=1&amp;sListOrder=DemoDay_D&amp;sPageSize=40&amp;sSearch=1&amp;sListType=list">\n<meta property="og:type" content="website">\n<meta property="og:description" content="엠파크 중고차 매매단지">\n\n<script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-34720473-1"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'UA-34720473-1\');\n</script>\n\n\n<script type="text/javascript">\n  var LoginID = "";\n  $(function(){\n      $(".share_area a").click(function(){\n          openShare("전체차량 : 내차구매","http://www.m-park.co.kr/buy/my_car_list.asp?gotopage=1&sListOrder=DemoDay_D&sPageSize=40&sSearch=1&sListType=list");\n          return false;\n      });\n\n\t /* $(".share-top-btn a").click(function(){ \n\t\t  openShare("전체차량 : 내차구매","http://www.m-park.co.kr/buy/my_car_list.asp?gotopage=1&sListOrder=DemoDay_D&sPageSize=40&sSearch=1&sListType=list");\n          return false;\n\t  });*/\n\n\t  $(".share-top-btn").click(function(){\n\t\t  $(this).toggleClass("on");\n\n\t\t  if($(this).hasClass("on")){\t\t\t  \n\t\t\topenShare("전체차량 : 내차구매","http://www.m-park.co.kr/buy/my_car_list.asp?gotopage=1&sListOrder=DemoDay_D&sPageSize=40&sSearch=1&sListType=list");\n\t\t\treturn false;\n\t\t  }\n\t  });\n  });\n</script>\n\n<script type="text/javascript">\n  var UserAgent = navigator.userAgent;\n\n  if (UserAgent.match(/iPhone|iPod|Android|Windows CE|BlackBerry|Symbian|Windows Phone|webOS|Opera Mini|Opera Mobi|POLARIS|IEMobile|lgtelecom|nokia|SonyEricsson/i) != null || UserAgent.match(/LG|SAMSUNG|Samsung/) != null) {\n      if(""!="true"){\n          location.href = "http://m.m-park.co.kr/buy/my_car_list.asp?gotopage=1&sListOrder=DemoDay_D&sPageSize=40&sSearch=1&sListType=list";\n      }\n  }\n</script>\n    <!-- <script src="/2018_renew/js/my_car.js"></script> -->\n    <script type="text/javascript">\n        var stype = "1";\n     ...

# %%
# 가격
price_list = driver.find_elements_by_css_selector("span.point")
price_num = [price.text for price in price_list]
price_num
# Out:
# ['780',
#  '2,510',
#  '3,000',
#  '1,710',
#  '2,190',
#  '2,080',
#  '1,750',
#  '1,890',
#  '1,660',
#  '3,740',
#  '2,110',
#  '1,630',
#  '1,920',
#  '1,970',
#  '2,130',
#  '920',
#  '2,500',
#  '2,330',
#  '1,480',
#  '5,300',
#  '1,080',
#  '1,020',
#  '1,350',
#  '4,740',
#  '3,300',
#  '7,140',
#  '1,680',
#  '1,520',
#  '1,420',
#  '1,860',
#  '810',
#  '590',
#  '1,710',
#  '1,510',
#  '1,260',
#  '850',
#  '1,390',
#  '1,340',
#  '3,140',
#  '4,340']

# %%
# 차량명
name_list = driver.find_elements_by_css_selector("div.title-box")
name_num = [name.text for name in name_list]
name_num
# Out:
# ['쉐보레/대우 더넥스트스파크 그래피티에디션 ',
#  '기아 스포티지더볼드 디젤2.0 2WD 인텔리전트',
#  'BMW 3시리즈(F30) 320d D',
#  '쌍용 티볼리에어 가솔린 4WD RX',
#  '기아 올뉴카니발 9인승 노블레스',
#  '현대 포터2 파워게이트 ',
#  '현대 포터2 초장축더블캡CRDi 스마트',
#  '현대 포터2 초장축더블캡CRDi 프리미엄',
#  '기아 봉고3 1톤킹캡초장축CRDi 럭셔리',
#  '기아 더뉴카니발 9인승 하이리무진 노블레스 스페셜',
#  '기아 더뉴봉고3 킹캡 ',
#  '현대 포터2 초장축슈퍼캡CRDi 스마트',
#  '현대 포터2 초장축슈퍼캡CRDi 스마트',
#  '기아 더뉴봉고3 킹캡 ',
#  '현대 쏘나타DN8 가솔린 2.0 프리미엄패밀리',
#  '르노삼성 QM5네오 가솔린2WD LE',
#  '기아 올뉴카니발 7인승 리무진 프레지던트',
#  '르노삼성 QM6 가솔린2WD RE',
#  '폭스바겐 티구안(1세대) 2.0TDI 컴포트',
#  '벤츠 GLC클래스(X253) AMG GLC43 4MATIC ',
#  '현대 제네시스 BH380(수출형) ',
#  '현대 제네시스 BH380(수출형) ',
#  '쌍용 티볼리 디젤 2WD LX',
#  '벤츠 E클래스(W213) E220d 4MATIC 익스클루시브 ',
#  '벤츠 뉴CLS클래스 CLS350 AMG스포츠패키지',
#  '제네시스 G80(2세대) 3.5터보 AWD ',
#  '쌍용 티볼리에어 가솔린 4WD IX',
#  '기아 올뉴카니발 9인승 럭셔리',
#  '현대 쏘나타뉴라이즈 2.0 CVVL 스마트 초이스',
#  '현대 쏘나타뉴라이즈 1.6터보프리미엄 ',
#  '쉐보레/대우 더넥스트스파크 LTZ ',
#  '쌍용 코란도C 클래시2WD 럭셔리',
#  '르노삼성 QM6 가솔린2WD RE',
#  '쌍용 코란도스포츠 익스트림 4WD ',
#  '현대 아반떼AD 1.6GDi 모던 스페셜',
#  '현대 i40살룬 1.7 VGT 모던',
#  '쌍용 티볼리에어 가솔린 2WD IX',
#  '현대 아반떼AD 1.6GDi 스마트 스페셜',
#  '현대 더뉴그랜저IG 2.5가솔린 프리미엄',
#  '기아 K8 2,4 가솔린 시그니처']

# %%
# 상태
sta_list = driver.find_elements_by_css_selector("div.car-info-l")
sta_num = [sta.text for sta in sta_list]
sta_num
# Out:
# ['2018년식 39,950Km 휘발유',
#  '2019년식 44,017Km 경유',
#  '2018년식 33,095Km 경유',
#  '2018년식 41,842Km 휘발유',
#  '2016년식 95,327Km 경유',
#  '2020년식 38,985Km 경유',
#  '2019년식 31,592Km 경유',
#  '2019년식 28,254Km 경유',
#  '2019년식 26,715Km 경유',
#  '2019년식 74,714Km 경유',
#  '2021년식 4,435Km 경유',
#  '2019년식 3,901Km 경유',
#  '2020년식 10,495Km 경유',
#  '2021년식 10,574Km 경유',
#  '2020 년식 29,731Km 휘발유',
#  '2015년식 73,083Km 휘발유',
#  '2016년식 52,350Km 경유',
#  '2018 년식 11,184Km 휘발유',
#  '2015년식 73,758Km 경유',
#  '2017 년식 24,000Km 휘발유',
#  '2012년식 72,573Km 휘발유',
#  '2012년식 64,475Km 휘발유',
#  '2017년식 66,359Km 경유',
#  '2018년식 44,759Km 경유',
#  '2014년식 33,280Km 휘발유',
#  '2021년식 16,085Km 휘발유',
#  '2018년식 28,641Km 휘발유',
#  '2015년식 140,316Km 경유',
#  '2019년식 130,358Km 휘발유',
#  '2018년식 54,080Km 휘발유',
#  '2017년식 30,342Km 휘발유',
#  '2012년식 132,615Km 경유',
#  '2017년식 92,356Km 휘발유',
#  '2016년식 75,742Km 경유',
#  '2016년식 98,899Km 휘발유',
#  '2012년식 143,912Km 경유',
#  '2017년식 53,367Km 휘발유',
#  '2018년식 64,446Km 휘발유',
#  '2020년식 7,895Km 휘발유',
#  '2022년식 3,093Km 휘발유']

# %%
driver = webdriver.Chrome("./driver/chromedriver")
driver.get("https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=001&aid=0012587876")

# %%
# 전달된 뉴스 url의 기사에서 기사제목 기사 입력시간을 반환하는 함수

def get_news_sub_info(url):
    
    # 1. 전달된 url에 접속 후 응답객체 반환
    headers = {"user-Agent":
           "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}
    result = requests.get(url,headers=headers)
    # 2. bs4 객체 생성
    bs_obj = BeautifulSoup(result.content,"html.parser")
    
    # 3. 필요 데이터 추출
    # 기사 제목 추출(태그 객체)
    title = bs_obj.find(id='articleTitle')
    # 기사 입력 시간 추출(태그 객체)
    time = bs_obj.find("span",{"class":"t11"})
    # 기사 내용 추출
    content = bs_obj.find(id='articleBodyContents')
    # 4.
    #time.sleep(2)
    #driver = webdriver.Chrome("./driver/chromedriver")
    driver.get(url)
    driver.page_source
    
    like_list = driver.find_elements_by_css_selector("span.u_likeit_text._count.num")
    like_num = [like.text for like in like_list]
    print(like_list)
    rep_list = driver.find_elements_by_css_selector("span.lo_txt")
    rep_num = [rep.text for rep in rep_list]
    print(rep_list)
    
    # 5. 수집 데이터 dict로 구성 후 반환
    dict_sub = {}
    dict_sub["기사제목"] = title.text
    dict_sub["기사 입력 시간"] = time.text
    dict_sub['좋아요 수'] = like_num
    dict_sub['댓글 수'] = rep_num
    #dict_sub["기사 내용"] = content.text.strip()
    
    return dict_sub

# %%
url = "https://news.naver.com"
headers={"User-Agent":
             "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}
result = requests.get(url,headers=headers)

bs_obj = BeautifulSoup(result.content,"html.parser")

#ul 태그 추출 : class:hdline_article_list
news_list = bs_obj.find("ul",{"class":"hdline_article_list"})
#모든 li 추출
lis = news_list.findAll("li")

#헤드라인뉴스 link 저장 - list
link_list=[]
for li in lis :
    a_tag = li.find("a")
    link_list.append("https://news.naver.com/"+a_tag["href"])
print(link_list)

driver = webdriver.Chrome("./driver/chromedriver")
import time
for number in range(len(link_list)) :
    res = get_news_sub_info(link_list[number])
    print(res)
    #time.sleep(2)
# Out:
# ['https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=008&aid=0004628325', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=214&aid=0001140740', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=437&aid=0000273247', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=028&aid=0002555918', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004950775']
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="730f4ba0-48e9-44b8-8bfe-8142d44caa23")>]
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="37dddd96-8350-4c60-b756-10e15594b366")>]
# {'기사제목': '남친 만나느라 사흘 집 비운 엄마…쓸쓸히 죽어간 3살 딸', '기사 입력 시간': '2021.08.09. 오후 1:35', '좋아요 수': ['21'], '댓글 수': ['']}
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="c53ba96a-2ff2-4e4a-8d63-0bfc06459abd")>]
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="92040309-bed4-4fe8-b15a-292fbce4cd96")>]
# {'기사제목': "법무부, 오늘 가석방 심사위…이재용 '주목'", '기사 입력 시간': '2021.08.09. 오후 12:08', '좋아요 수': ['67'], '댓글 수': ['106']}
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="28e2a0b5-cee9-48a0-a5b6-ffcfa2156c07")>]
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="da3fe01e-4d4f-4396-83db-c91d7e33b35a")>]
# {'기사제목': '전두환, 사자명예훼손 항소심 출석…왜 입장 바꿨나?', '기사 입력 시간': '2021.08.09. 오전 8:32', '좋아요 수': ['72'], '댓글 수': ['106']}
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="f9aa3780-d410-4cd1-b3c9-537e91287c0c")>]
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="66fd2b12-9317-4645-99ec-9d0cf839f091")>]
# {'기사제목': '올해도 광복절 ‘대규모 집회’ 예고한 전광훈…경찰청장 “엄정 대응”', '기사 입력 시간': '2021.08.09. 오후 2:08', '좋아요 수': ['44'], '댓글 수': ['62']}
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="4c58ac83-db35-454d-8911-70e8bae4e20d")>]
# [<selenium.webdriver.remote.webelement.WebElement (session="ff36f92fe378afbf2fc3ea3770050bfc", element="14470cf5-961a-46fb-85b2-fc927600a807")>]
# {'기사제목': "오늘부터 8PM '클릭전쟁'…백신 사전예약 10부제, 먹통 해결할까", '기사 입력 시간': '2021.08.09. 오전 11:33', '좋아요 수': ['43'], '댓글 수': ['']}

# %%
for number in range(len(link_list)) :
    res = get_news_sub_info(link_list[number])
    print(res)
# Out:
# {'기사제목': '[속보] 2학기에 3단계까지 전면등교…4단계에도 3분의 1이상', '기사 입력 시간': '2021.08.09. 오후 2:44', '좋아요 수': [], '댓글 수': ['']}
# {'기사제목': '[시그널] 강성부 "쌍용차, 전기차 진출 더없이 좋은 요건"...에디슨모터스 손잡고 참전', '기사 입력 시간': '2021.08.09. 오전 11:48', '좋아요 수': [], '댓글 수': ['']}
# {'기사제목': '부패한 시신으로 발견된 3살 여아…친모 긴급체포', '기사 입력 시간': '2021.08.09. 오전 11:14', '좋아요 수': [], '댓글 수': ['']}
# {'기사제목': '생후 2주 아들 살해 친부 징역 25년·친모 징역 7년 선고', '기사 입력 시간': '2021.08.09. 오후 1:17', '좋아요 수': [], '댓글 수': ['']}
# {'기사제목': '검찰, 지난해 광복절 불법집회 주도 전광훈 불구속 기소', '기사 입력 시간': '2021.08.09. 오전 11:48', '좋아요 수': [], '댓글 수': ['']}

# %%
# 크롬 드라이버를 통한 네이버 접속

driver = webdriver.Chrome("./driver/chromedriver")
driver.get("https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=001&aid=0012587876")
